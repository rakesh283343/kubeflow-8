# %%
# !pip show kubeflow-fairing
# !pip install pyyaml
# Out:
# Name: kubeflow-fairing
# Version: 1.0.1
# Summary: Kubeflow Fairing Python SDK.
# Home-page: https://github.com/kubeflow/fairing
# Author: Kubeflow Authors
# Author-email: hejinchi@cn.ibm.com
# License: Apache License Version 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: six, requests, boto3, numpy, ibm-cos-sdk, kubeflow-tfjob, google-auth, setuptools, azure-mgmt-storage, kubernetes, grpcio, kfserving, httplib2, python-dateutil, notebook, docker, nbconvert, google-api-python-client, future, kubeflow-pytorchjob, google-cloud-storage, oauth2client, google-cloud-logging, cloudpickle, retrying, urllib3, tornado, azure-storage-file
# Required-by:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (5.3.1)

# %%
DOCKER_REGISTRY = 'index.docker.io/insoopark'
my_namespace = 'admin'

# %%
pv_name = 'kubeflow-mnist'
pvc_name = 'mnist-pvc'

# %%
from kubernetes import client as k8s_client
from kubernetes import config as k8s_config
from kubeflow.fairing.utils import is_running_in_k8s
import yaml

if is_running_in_k8s():
    k8s_config.load_incluster_config()
else:
    k8s_config.load_kube_config()

k8s_core_api = k8s_client.CoreV1Api()

# %%
num_chief = 1 #number of Chief in TFJob 
num_ps = 1  #number of PS in TFJob 
num_workers = 1  #number of Worker in TFJob 
model_dir = "/mnt"
export_path = "/mnt/export" 
train_steps = "1000"
batch_size = "100"
learning_rate = "0.01"

# %%
import uuid
from kubeflow import fairing   
from kubeflow.fairing.kubernetes.utils import mounting_pvc
from kubeflow.fairing.kubernetes import utils as k8s_utils

tfjob_name = f'mnist-training-{uuid.uuid4().hex[:4]}'

output_map =  {
    "Dockerfile": "Dockerfile",
    "mnist.py": "mnist.py"
}

command=["python",
         "/opt/mnist.py",
         "--tf-model-dir=" + model_dir,
         "--tf-export-dir=" + export_path,
         "--tf-train-steps=" + train_steps,
         "--tf-batch-size=" + batch_size,
         "--tf-learning-rate=" + learning_rate]

fairing.config.set_preprocessor('python', input_files=["mnist.py"], executable="mnist.py")
fairing.config.set_builder(
            name='append',
            image_name='mnist',
            base_image='tensorflow/tensorflow:1.15.2-py3',
            registry=DOCKER_REGISTRY, 
            push=True)
fairing.config.set_deployer('tfjob', namespace='admin', stream_log=False, job_name=tfjob_name, 
                            pod_spec_mutators=[k8s_utils.get_resource_mutator(cpu=1, memory=2),
                                               mounting_pvc(pvc_name=pvc_name, pvc_mount_path=model_dir)])

fairing.config.run()
# Out:
# [W 200829 08:10:13 utils:51] The function mounting_pvc has been deprecated,                     please use `volume_mounts`
# [I 200829 08:10:13 config:134] Using preprocessor: <kubeflow.fairing.preprocessors.base.BasePreProcessor object at 0x7fbe51a52940>
# [I 200829 08:10:13 config:136] Using builder: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7fbe53e2b908>
# [I 200829 08:10:13 config:138] Using deployer: <kubeflow.fairing.deployers.tfjob.tfjob.TfJob object at 0x7fbe56bab9e8>
# [W 200829 08:10:13 append:50] Building image using Append builder...
# [I 200829 08:10:13 base:107] Creating docker context: /tmp/fairing_context_3l_hbl9f
# [I 200829 08:10:13 docker_creds_:234] Loading Docker credentials for repository 'tensorflow/tensorflow:1.15.2-py3'
# [W 200829 08:10:14 append:54] Image successfully built in 0.8786057229990547s.
# [W 200829 08:10:14 append:94] Pushing image index.docker.io/insoopark/mnist:2FA981DD...
# [I 200829 08:10:14 docker_creds_:234] Loading Docker credentials for repository 'index.docker.io/insoopark/mnist:2FA981DD'
# [W 200829 08:10:14 append:81] Uploading index.docker.io/insoopark/mnist:2FA981DD
# [I 200829 08:10:15 docker_session_:280] Layer sha256:8e380181f1d6ac5c8cba8bea118d7debf84cffc710ed86fb4801fd91314fbbc8 exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:5c939e3a4d1097af8d3292ad3a41d3caa846f6333b91f2dd22b972bc2d19c5b5 exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:2d8b4073f9d39e80ce92e297fe9b8ce758ce42efea2e571680b18da0fa518ac1 exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:6ad1a4724db544c56f6ec06f51e23888ac20d4ec05cd03eed907a9b1bfc13698 exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:651c9d2d6c4f37c56a221259e033e7e2353b698139c2ff950623ca28d64a9837 exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:19a861ea6baff71b05cd577478984c3e62cf0177bf74468d0aca551f5fcb891c exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:3ecca60901ea27296d489f07a0772f7be13ba717cf6b8b9aab2e7371c8d28c55 exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:8b4189038ec35a8fd98f1cbde988559fb2d010f158056f788bd1e1edee3e1d4f exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:be48143b2f7680d6c336e04617cbda8592a70733f7b6380c6f9d137d38bbb8aa exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:c63719cdbe7ae254b453dba06fb446f583b503f2a2c15becc83f8c5bc7a705e0 exists, skipping
# [I 200829 08:10:15 docker_session_:280] Layer sha256:cde5a12335848fad1659e2c6026b0c266902d2671a6f626ae0c0d178222b3ae6 exists, skipping
# [I 200829 08:10:16 docker_session_:284] Layer sha256:9b6f3b34d4955bcc889053ff348f9f5b68f89b541946b6f78349bddce72b865e pushed.
# [I 200829 08:10:16 docker_session_:334] Finished upload of: index.docker.io/insoopark/mnist:2FA981DD
# [W 200829 08:10:16 append:99] Pushed image index.docker.io/insoopark/mnist:2FA981DD in 2.0966176799993264s.
# [W 200829 08:10:16 job:101] The tfjob mnist-training-094d launched.
# (<kubeflow.fairing.preprocessors.base.BasePreProcessor at 0x7fbe51a52940>,
#  <kubeflow.fairing.builders.append.append.AppendBuilder at 0x7fbe53e2b908>,
#  <kubeflow.fairing.deployers.tfjob.tfjob.TfJob at 0x7fbe56bab9e8>)

# %%
from kubeflow.tfjob import TFJobClient
tfjob_client = TFJobClient()

tfjob_client.get(tfjob_name, namespace=my_namespace)
# Out:
# {'apiVersion': 'kubeflow.org/v1',
#  'kind': 'TFJob',
#  'metadata': {'creationTimestamp': '2020-08-29T08:10:16Z',
#   'generateName': 'fairing-tfjob-',
#   'generation': 1,
#   'labels': {'fairing-deployer': 'tfjob',
#    'fairing-id': '12abf6e6-e9cf-11ea-bf92-26a9a7e45509'},
#   'name': 'mnist-training-094d',
#   'namespace': 'admin',
#   'resourceVersion': '48493',
#   'selfLink': '/apis/kubeflow.org/v1/namespaces/admin/tfjobs/mnist-training-094d',
#   'uid': '241628ef-f436-416b-8434-41c7d7d88f0c'},
#  'spec': {'tfReplicaSpecs': {'Worker': {'replicas': 1,
#     'template': {'metadata': {'annotations': {'sidecar.istio.io/inject': 'false'},
#       'labels': {'fairing-deployer': 'tfjob',
#        'fairing-id': '12abf6e6-e9cf-11ea-bf92-26a9a7e45509'},
#       'name': 'fairing-deployer'},
#      'spec': {'containers': [{'command': ['python', '/app/mnist.py'],
#         'env': [{'name': 'FAIRING_RUNTIME', 'value': '1'}],
#         'image': 'index.docker.io/insoopark/mnist:2FA981DD',
#         'name': 'tensorflow',
#         'resources': {'limits': {'cpu': 1, 'memory': '1.86Gi'}},
#         'securityContext': {'runAsUser': 0},
#         'volumeMounts': [{'mountPath': '/mnt',
#           'name': 'fairing-volume-mnist-pvc'}],
#         'workingDir': '/app/'}],
#       'restartPolicy': 'Never',
#       'volumes': [{'name': 'fairing-volume-mnist-pvc',
#         'persistentVolumeClaim': {'claimName': 'mnist-pvc'}}]}}}}},
#  'status': {'conditions': [{'lastTransitionTime': '2020-08-29T08:10:16Z',
#     'lastUpdateTime': '2020-08-29T08:10:16Z',
#     'message': 'TFJob mnist-training-094d is created.',
#     'reason': 'TFJobCreated',
#     'status': 'True',
#     'type': 'Created'},
#    {'lastTransitionTime': '2020-08-29T08:10:18Z',
#     'lastUpdateTime': '2020-08-29T08:10:18Z',
#     'message': 'TFJob mnist-training-094d is running.',
#     'reason': 'TFJobRunning',
#     'status': 'True',
#     'type': 'Running'}],
#   'replicaStatuses': {'Worker': {'active': 1}},
#   'startTime': '2020-08-29T08:10:16Z'}}

# %%
tfjob_client.wait_for_job(tfjob_name, namespace=my_namespace, watch=True)
# Out:
# NAME                           STATE                TIME
# mnist-training-094d            Running              2020-08-29T08:10:18Z
# mnist-training-094d            Succeeded            2020-08-29T08:12:09Z

# %%
tfjob_client.is_job_succeeded(tfjob_name, namespace=my_namespace)
# Out:
# True

# %%
tfjob_client.get_logs(tfjob_name, namespace=my_namespace)
# Out:
# [I 200829 08:12:09 tf_job_client:386] The logs of Pod mnist-training-094d-worker-0:
#      WARNING:tensorflow:From /app/mnist.py:240: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
#     WARNING:tensorflow:From /app/mnist.py:155: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
#     W0829 08:10:20.518902 140056513029952 module_wrapper.py:139] From /app/mnist.py:155: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
#     WARNING:tensorflow:From /app/mnist.py:155: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
#     W0829 08:10:20.519200 140056513029952 module_wrapper.py:139] From /app/mnist.py:155: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
#     WARNING:tensorflow:From /app/mnist.py:160: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#     W0829 08:10:20.520934 140056513029952 module_wrapper.py:139] From /app/mnist.py:160: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
#     INFO:tensorflow:TF_CONFIG {}
#     I0829 08:10:20.521109 140056513029952 mnist.py:160] TF_CONFIG {}
#     INFO:tensorflow:cluster=None job_name=None task_index=None
#     I0829 08:10:20.521793 140056513029952 mnist.py:166] cluster=None job_name=None task_index=None
#     INFO:tensorflow:Will export model
#     I0829 08:10:20.521903 140056513029952 mnist.py:171] Will export model
#     WARNING:tensorflow:
#     The TensorFlow contrib module will not be included in TensorFlow 2.0.
#     For more information, please see:
#       * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#       * https://github.com/tensorflow/addons
#       * https://github.com/tensorflow/io (for I/O related ops)
#     If you depend on functionality not listed there, please file an issue.
#
#     W0829 08:10:20.522097 140056513029952 lazy_loader.py:50]
#     The TensorFlow contrib module will not be included in TensorFlow 2.0.
#     For more information, please see:
#       * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#       * https://github.com/tensorflow/addons
#       * https://github.com/tensorflow/io (for I/O related ops)
#     If you depend on functionality not listed there, please file an issue.
#
#     WARNING:tensorflow:From /app/mnist.py:176: load_mnist (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#     W0829 08:10:20.934796 140056513029952 deprecation.py:323] From /app/mnist.py:176: load_mnist (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:300: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#     W0829 08:10:20.935106 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:300: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please write your own downloading logic.
#     W0829 08:10:20.935259 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please write your own downloading logic.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use urllib or similar directly.
#     W0829 08:10:20.935678 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use urllib or similar directly.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use tf.data to implement this functionality.
#     W0829 08:10:21.351901 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use tf.data to implement this functionality.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use tf.data to implement this functionality.
#     W0829 08:10:21.713480 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use tf.data to implement this functionality.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#     W0829 08:10:21.911674 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#     WARNING:tensorflow:From /app/mnist.py:177: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
#     W0829 08:10:22.224565 140056513029952 module_wrapper.py:139] From /app/mnist.py:177: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
#     WARNING:tensorflow:From /app/mnist.py:177: The name tf.estimator.inputs.numpy_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.numpy_input_fn instead.
#
#     W0829 08:10:22.224835 140056513029952 module_wrapper.py:139] From /app/mnist.py:177: The name tf.estimator.inputs.numpy_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.numpy_input_fn instead.
#
#     WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp6f9094wi
#     W0829 08:10:22.225874 140056513029952 estimator.py:1821] Using temporary folder as model directory: /tmp/tmp6f9094wi
#     INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp6f9094wi', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
#     graph_options {
#       rewrite_options {
#         meta_optimizer_iterations: ONE
#       }
#     }
#     , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f61421c3f28>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#     I0829 08:10:22.226338 140056513029952 estimator.py:212] Using config: {'_model_dir': '/tmp/tmp6f9094wi', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
#     graph_options {
#       rewrite_options {
#         meta_optimizer_iterations: ONE
#       }
#     }
#     , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f61421c3f28>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#     INFO:tensorflow:Not using Distribute Coordinator.
#     I0829 08:10:22.226897 140056513029952 estimator_training.py:186] Not using Distribute Coordinator.
#     INFO:tensorflow:Running training and evaluation locally (non-distributed).
#     I0829 08:10:22.227107 140056513029952 training.py:612] Running training and evaluation locally (non-distributed).
#     INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
#     I0829 08:10:22.227318 140056513029952 training.py:700] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
#     W0829 08:10:22.233600 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     To construct input pipelines, use the `tf.data` module.
#     W0829 08:10:22.248105 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     To construct input pipelines, use the `tf.data` module.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     To construct input pipelines, use the `tf.data` module.
#     W0829 08:10:22.249275 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     To construct input pipelines, use the `tf.data` module.
#     INFO:tensorflow:Calling model_fn.
#     I0829 08:10:22.257719 140056513029952 estimator.py:1148] Calling model_fn.
#     WARNING:tensorflow:From /app/mnist.py:76: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
#     W0829 08:10:22.259188 140056513029952 module_wrapper.py:139] From /app/mnist.py:76: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
#     WARNING:tensorflow:From /app/mnist.py:82: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use `tf.keras.layers.Conv2D` instead.
#     W0829 08:10:22.259554 140056513029952 deprecation.py:323] From /app/mnist.py:82: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use `tf.keras.layers.Conv2D` instead.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use `layer.__call__` method instead.
#     W0829 08:10:22.260716 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Please use `layer.__call__` method instead.
#     WARNING:tensorflow:From /app/mnist.py:84: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use keras.layers.MaxPooling2D instead.
#     W0829 08:10:22.277129 140056513029952 deprecation.py:323] From /app/mnist.py:84: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use keras.layers.MaxPooling2D instead.
#     WARNING:tensorflow:From /app/mnist.py:100: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use keras.layers.Dense instead.
#     W0829 08:10:22.298398 140056513029952 deprecation.py:323] From /app/mnist.py:100: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use keras.layers.Dense instead.
#     WARNING:tensorflow:From /app/mnist.py:104: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use keras.layers.dropout instead.
#     W0829 08:10:22.314555 140056513029952 deprecation.py:323] From /app/mnist.py:104: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use keras.layers.dropout instead.
#     WARNING:tensorflow:From /app/mnist.py:125: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#     W0829 08:10:22.344527 140056513029952 module_wrapper.py:139] From /app/mnist.py:125: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use tf.where in 2.0, which has the same broadcast rule as np.where
#     W0829 08:10:22.354083 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     Use tf.where in 2.0, which has the same broadcast rule as np.where
#     WARNING:tensorflow:From /app/mnist.py:129: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
#     W0829 08:10:22.362513 140056513029952 module_wrapper.py:139] From /app/mnist.py:129: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
#     WARNING:tensorflow:From /app/mnist.py:132: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
#     W0829 08:10:22.362749 140056513029952 module_wrapper.py:139] From /app/mnist.py:132: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
#     INFO:tensorflow:Done calling model_fn.
#     I0829 08:10:22.453153 140056513029952 estimator.py:1150] Done calling model_fn.
#     INFO:tensorflow:Create CheckpointSaverHook.
#     I0829 08:10:22.454571 140056513029952 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
#     INFO:tensorflow:Graph was finalized.
#     I0829 08:10:22.571452 140056513029952 monitored_session.py:240] Graph was finalized.
#     2020-08-29 08:10:22.571889: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
#     2020-08-29 08:10:22.577927: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
#     2020-08-29 08:10:22.578722: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3dca4f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
#     2020-08-29 08:10:22.578753: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#     INFO:tensorflow:Running local_init_op.
#     I0829 08:10:22.680793 140056513029952 session_manager.py:500] Running local_init_op.
#     INFO:tensorflow:Done running local_init_op.
#     I0829 08:10:22.687595 140056513029952 session_manager.py:502] Done running local_init_op.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     To construct input pipelines, use the `tf.data` module.
#     W0829 08:10:22.706686 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     To construct input pipelines, use the `tf.data` module.
#     INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp6f9094wi/model.ckpt.
#     I0829 08:10:22.931901 140056513029952 basic_session_run_hooks.py:606] Saving checkpoints for 0 into /tmp/tmp6f9094wi/model.ckpt.
#     INFO:tensorflow:loss = 2.304174, step = 1
#     I0829 08:10:23.664298 140056513029952 basic_session_run_hooks.py:262] loss = 2.304174, step = 1
#     INFO:tensorflow:global_step/sec: 1.92687
#     I0829 08:11:15.561240 140056513029952 basic_session_run_hooks.py:692] global_step/sec: 1.92687
#     INFO:tensorflow:loss = 2.1581407, step = 101 (51.898 sec)
#     I0829 08:11:15.562354 140056513029952 basic_session_run_hooks.py:260] loss = 2.1581407, step = 101 (51.898 sec)
#     INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmp6f9094wi/model.ckpt.
#     I0829 08:12:06.571780 140056513029952 basic_session_run_hooks.py:606] Saving checkpoints for 200 into /tmp/tmp6f9094wi/model.ckpt.
#     INFO:tensorflow:Calling model_fn.
#     I0829 08:12:06.686526 140056513029952 estimator.py:1148] Calling model_fn.
#     WARNING:tensorflow:From /app/mnist.py:137: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
#     W0829 08:12:06.780379 140056513029952 module_wrapper.py:139] From /app/mnist.py:137: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
#     INFO:tensorflow:Done calling model_fn.
#     I0829 08:12:06.798545 140056513029952 estimator.py:1150] Done calling model_fn.
#     INFO:tensorflow:Starting evaluation at 2020-08-29T08:12:06Z
#     I0829 08:12:06.818190 140056513029952 evaluation.py:255] Starting evaluation at 2020-08-29T08:12:06Z
#     INFO:tensorflow:Graph was finalized.
#     I0829 08:12:06.894929 140056513029952 monitored_session.py:240] Graph was finalized.
#     INFO:tensorflow:Restoring parameters from /tmp/tmp6f9094wi/model.ckpt-200
#     I0829 08:12:06.896573 140056513029952 saver.py:1284] Restoring parameters from /tmp/tmp6f9094wi/model.ckpt-200
#     INFO:tensorflow:Running local_init_op.
#     I0829 08:12:06.949262 140056513029952 session_manager.py:500] Running local_init_op.
#     INFO:tensorflow:Done running local_init_op.
#     I0829 08:12:06.965853 140056513029952 session_manager.py:502] Done running local_init_op.
#     INFO:tensorflow:Evaluation [1/1]
#     I0829 08:12:07.167926 140056513029952 evaluation.py:167] Evaluation [1/1]
#     INFO:tensorflow:Finished evaluation at 2020-08-29-08:12:07
#     I0829 08:12:07.293212 140056513029952 evaluation.py:275] Finished evaluation at 2020-08-29-08:12:07
#     INFO:tensorflow:Saving dict for global step 200: accuracy = 0.703125, global_step = 200, loss = 1.0854478
#     I0829 08:12:07.293505 140056513029952 estimator.py:2049] Saving dict for global step 200: accuracy = 0.703125, global_step = 200, loss = 1.0854478
#     INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: /tmp/tmp6f9094wi/model.ckpt-200
#     I0829 08:12:07.331799 140056513029952 estimator.py:2109] Saving 'checkpoint_path' summary for global step 200: /tmp/tmp6f9094wi/model.ckpt-200
#     INFO:tensorflow:Performing the final export in the end of training.
#     I0829 08:12:07.332628 140056513029952 exporter.py:410] Performing the final export in the end of training.
#     WARNING:tensorflow:From /app/mnist.py:145: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#     W0829 08:12:07.337581 140056513029952 module_wrapper.py:139] From /app/mnist.py:145: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#     INFO:tensorflow:Calling model_fn.
#     I0829 08:12:07.338647 140056513029952 estimator.py:1148] Calling model_fn.
#     INFO:tensorflow:Done calling model_fn.
#     I0829 08:12:07.414440 140056513029952 estimator.py:1150] Done calling model_fn.
#     WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
#     W0829 08:12:07.414720 140056513029952 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
#     INFO:tensorflow:Signatures INCLUDED in export for Classify: None
#     I0829 08:12:07.415103 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Classify: None
#     INFO:tensorflow:Signatures INCLUDED in export for Regress: None
#     I0829 08:12:07.415203 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Regress: None
#     INFO:tensorflow:Signatures INCLUDED in export for Predict: ['classes', 'serving_default']
#     I0829 08:12:07.415259 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Predict: ['classes', 'serving_default']
#     INFO:tensorflow:Signatures INCLUDED in export for Train: None
#     I0829 08:12:07.415304 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Train: None
#     INFO:tensorflow:Signatures INCLUDED in export for Eval: None
#     I0829 08:12:07.415352 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Eval: None
#     INFO:tensorflow:Restoring parameters from /tmp/tmp6f9094wi/model.ckpt-200
#     I0829 08:12:07.437453 140056513029952 saver.py:1284] Restoring parameters from /tmp/tmp6f9094wi/model.ckpt-200
#     INFO:tensorflow:Assets added to graph.
#     I0829 08:12:07.464778 140056513029952 builder_impl.py:665] Assets added to graph.
#     INFO:tensorflow:No assets to write.
#     I0829 08:12:07.464991 140056513029952 builder_impl.py:460] No assets to write.
#     INFO:tensorflow:SavedModel written to: /tmp/tmp6f9094wi/export/mnist/temp-b'1598688727'/saved_model.pb
#     I0829 08:12:07.508671 140056513029952 builder_impl.py:425] SavedModel written to: /tmp/tmp6f9094wi/export/mnist/temp-b'1598688727'/saved_model.pb
#     INFO:tensorflow:Loss for final step: 1.1452962.
#     I0829 08:12:07.547894 140056513029952 estimator.py:371] Loss for final step: 1.1452962.
#     WARNING:tensorflow:From /app/mnist.py:232: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     This function has been renamed, use `export_saved_model` instead.
#     W0829 08:12:07.548670 140056513029952 deprecation.py:323] From /app/mnist.py:232: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
#     Instructions for updating:
#     This function has been renamed, use `export_saved_model` instead.
#     INFO:tensorflow:Calling model_fn.
#     I0829 08:12:07.558832 140056513029952 estimator.py:1148] Calling model_fn.
#     INFO:tensorflow:Done calling model_fn.
#     I0829 08:12:07.716488 140056513029952 estimator.py:1150] Done calling model_fn.
#     INFO:tensorflow:Signatures INCLUDED in export for Classify: None
#     I0829 08:12:07.717185 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Classify: None
#     INFO:tensorflow:Signatures INCLUDED in export for Regress: None
#     I0829 08:12:07.717364 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Regress: None
#     INFO:tensorflow:Signatures INCLUDED in export for Predict: ['classes', 'serving_default']
#     I0829 08:12:07.717446 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Predict: ['classes', 'serving_default']
#     INFO:tensorflow:Signatures INCLUDED in export for Train: None
#     I0829 08:12:07.717503 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Train: None
#     INFO:tensorflow:Signatures INCLUDED in export for Eval: None
#     I0829 08:12:07.717550 140056513029952 export_utils.py:170] Signatures INCLUDED in export for Eval: None
#     INFO:tensorflow:Restoring parameters from /tmp/tmp6f9094wi/model.ckpt-200
#     I0829 08:12:07.739211 140056513029952 saver.py:1284] Restoring parameters from /tmp/tmp6f9094wi/model.ckpt-200
#     INFO:tensorflow:Assets added to graph.
#     I0829 08:12:07.765530 140056513029952 builder_impl.py:665] Assets added to graph.
#     INFO:tensorflow:No assets to write.
#     I0829 08:12:07.765855 140056513029952 builder_impl.py:460] No assets to write.
#     INFO:tensorflow:SavedModel written to: /mnt/export/mnist/temp-b'1598688727'/saved_model.pb
#     I0829 08:12:07.815854 140056513029952 builder_impl.py:425] SavedModel written to: /mnt/export/mnist/temp-b'1598688727'/saved_model.pb
#     Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
#     Extracting /tmp/data/train-images-idx3-ubyte.gz
#     Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
#     Extracting /tmp/data/train-labels-idx1-ubyte.gz
#     Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
#     Extracting /tmp/data/t10k-images-idx3-ubyte.gz
#     Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
#     Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
#     Train and evaluate
#     Training done
#     Export saved model
#     Done exporting the model: mnist/

# %%
from kubernetes import client

from kfserving import KFServingClient
from kfserving import constants
from kfserving import utils
from kfserving import V1alpha2EndpointSpec
from kfserving import V1alpha2PredictorSpec
from kfserving import V1alpha2TensorflowSpec
from kfserving import V1alpha2InferenceServiceSpec
from kfserving import V1alpha2InferenceService
from kubernetes.client import V1ResourceRequirements

# %%
namespace = utils.get_default_target_namespace()
print(namespace)
# Out:
# admin

# %%
isvc_name = f'mnist-service-{uuid.uuid4().hex[:4]}'
api_version = constants.KFSERVING_GROUP + '/' + constants.KFSERVING_VERSION
# due to cpu resource is not enough, inference service is not ready. changed from 1Gi to 100m
default_endpoint_spec = V1alpha2EndpointSpec(
                          predictor=V1alpha2PredictorSpec(
                            tensorflow=V1alpha2TensorflowSpec(
                              storage_uri='pvc://mnist-pvc/export/mnist',
                              resources=V1ResourceRequirements(
                                  requests={'cpu':'100m','memory':'1Gi'},
                                  limits={'cpu':'100m', 'memory':'1Gi'}))))
    
isvc = V1alpha2InferenceService(api_version=api_version,
                          kind=constants.KFSERVING_KIND,
                          metadata=client.V1ObjectMeta(
                              name=isvc_name, namespace=namespace),
                          spec=V1alpha2InferenceServiceSpec(default=default_endpoint_spec))

# %%
KFServing = KFServingClient()
KFServing.create(isvc)
# Out:
# {'apiVersion': 'serving.kubeflow.org/v1alpha2',
#  'kind': 'InferenceService',
#  'metadata': {'creationTimestamp': '2020-08-29T09:16:56Z',
#   'generation': 1,
#   'name': 'mnist-service-6822',
#   'namespace': 'admin',
#   'resourceVersion': '72074',
#   'selfLink': '/apis/serving.kubeflow.org/v1alpha2/namespaces/admin/inferenceservices/mnist-service-6822',
#   'uid': '508b7fc3-ef74-42d3-b6a7-4ae9d604fef9'},
#  'spec': {'default': {'predictor': {'tensorflow': {'resources': {'limits': {'cpu': '100m',
#        'memory': '1Gi'},
#       'requests': {'cpu': '100m', 'memory': '1Gi'}},
#      'runtimeVersion': '1.14.0',
#      'storageUri': 'pvc://mnist-pvc/export/mnist'}}}}}

# %%
KFServing.get(isvc_name, namespace=namespace, watch=True, timeout_seconds=120)
# Out:
# NAME                 READY      DEFAULT_TRAFFIC CANARY_TRAFFIC  URL
# mnist-service-6822   False
# mnist-service-6822   False
# mnist-service-6822   True       100                             http://mnist-service-6822.admin.example.com/v1/...

# %%
# can get ip address from (kubectl -n istio-system get service istio-ingressgateway -o jsonpath='{.spec.clusterIP}')
# 아래 주소로 날리면 302 응답이 떨어짐. -L 옵션을 줘야 함 
# 외부에서 외부 IP로 접속하면 (GCP의 경우 404 에러 발생 -> 쩝. 당연함)
# !curl -L -v -H "mnist-service-6822.admin.svc.cluster.local" http://10.99.127.209/v1/models/mnist-service-6822:predict -d @./input.json
# Out:
# *   Trying 10.99.127.209...
# * TCP_NODELAY set
# * Connected to 10.99.127.209 (10.99.127.209) port 80 (#0)
# > POST /v1/models/mnist-service-6822:predict HTTP/1.1
# > Host: 10.99.127.209
# > User-Agent: curl/7.58.0
# > Accept: */*
# > Content-Length: 2052
# > Content-Type: application/x-www-form-urlencoded
# > Expect: 100-continue
# >
# < HTTP/1.1 100 Continue
# * We are completely uploaded and fine
# < HTTP/1.1 302 Found
# < location: /dex/auth?client_id=kubeflow-oidc-authservice&redirect_uri=%2Flogin%2Foidc&response_type=code&scope=profile+email+groups+openid&state=MTU5ODY5NDQ0MXxFd3dBRUVneFpFMW5iRVZvV0dkMWJ6VTNjbkU9fLWhcF0UsHRqJDHmshA1KKI5RYx1OIj6xMz01jsj6PXS
# < date: Sat, 29 Aug 2020 09:47:21 GMT
# < content-length: 0
# < x-envoy-upstream-service-time: 3
# < server: envoy
# <
# * Connection #0 to host 10.99.127.209 left intact
# * Issue another request to this URL: 'http://10.99.127.209/dex/auth?client_id=kubeflow-oidc-authservice&redirect_uri=%2Flogin%2Foidc&response_type=code&scope=profile+email+groups+openid&state=MTU5ODY5NDQ0MXxFd3dBRUVneFpFMW5iRVZvV0dkMWJ6VTNjbkU9fLWhcF0UsHRqJDHmshA1KKI5RYx1OIj6xMz01jsj6PXS'
# * Switch from POST to GET
# * Found bundle for host 10.99.127.209: 0x55fc184d0850 [can pipeline]
# * Re-using existing connection! (#0) with host 10.99.127.209
# * Connected to 10.99.127.209 (10.99.127.209) port 80 (#0)
# > GET /dex/auth?client_id=kubeflow-oidc-authservice&redirect_uri=%2Flogin%2Foidc&response_type=code&scope=profile+email+groups+openid&state=MTU5ODY5NDQ0MXxFd3dBRUVneFpFMW5iRVZvV0dkMWJ6VTNjbkU9fLWhcF0UsHRqJDHmshA1KKI5RYx1OIj6xMz01jsj6PXS HTTP/1.1
# > Host: 10.99.127.209
# > User-Agent: curl/7.58.0
# > Accept: */*
# >
# < HTTP/1.1 302 Found
# < content-type: text/html; charset=utf-8
# < location: /dex/auth/local?req=cghndsoxmepuvuq4g3teso42p
# < date: Sat, 29 Aug 2020 09:47:21 GMT
# < content-length: 68
# < x-envoy-upstream-service-time: 7
# < server: envoy
# <
# * Ignoring the response-body
# * Connection #0 to host 10.99.127.209 left intact
# * Issue another request to this URL: 'http://10.99.127.209/dex/auth/local?req=cghndsoxmepuvuq4g3teso42p'
# * Found bundle for host 10.99.127.209: 0x55fc184d0850 [can pipeline]
# * Re-using existing connection! (#0) with host 10.99.127.209
# * Connected to 10.99.127.209 (10.99.127.209) port 80 (#0)
# > GET /dex/auth/local?req=cghndsoxmepuvuq4g3teso42p HTTP/1.1
# > Host: 10.99.127.209
# > User-Agent: curl/7.58.0
# > Accept: */*
# >
# < HTTP/1.1 200 OK
# < date: Sat, 29 Aug 2020 09:47:21 GMT
# < content-length: 1497
# < content-type: text/html; charset=utf-8
# < x-envoy-upstream-service-time: 17
# < server: envoy
# <
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <title>dex</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link href="../static/main.css" rel="stylesheet">
#     <link href="../theme/styles.css" rel="stylesheet">
#     <link rel="icon" href="../theme/favicon.png">
#   </head>
#
#   <body class="theme-body">
#     <div class="theme-navbar">
#       <div class="theme-navbar__logo-wrap">
#         <img class="theme-navbar__logo" src="../theme/logo.png">
#       </div>
#     </div>
#
#     <div class="dex-container">
#
#
#
# <div class="theme-panel">
#   <h2 class="theme-heading">Log in to Your Account</h2>
#   <form method="post" action="/dex/auth/local?req=cghndsoxmepuvuq4g3teso42p">
#     <div class="theme-form-row">
#       <div class="theme-form-label">
#         <label for="userid">Email Address</label>
#       </div>
# 	  <input tabindex="1" required id="login" name="login" type="text" class="theme-form-input" placeholder="email address"  autofocus />
#     </div>
#     <div class="theme-form-row">
#       <div class="theme-form-label">
#         <label for="password">Password</label>
#       </div>
# 	  <input tabindex="2" required id="password" name="password" type="password" class="theme-form-input" placeholder="password" />
#     </div>
#
#
#
#     <button tabindex="3" id="submit-login" type="submit" class="dex-btn theme-btn--primary">Login</button>
#
#   </form>
#
# </div>
#
#     </div>
#   </body>
# </html>
#
# * Connection #0 to host 10.99.127.209 left intact

# %%
KFServing.delete(isvc_name, namespace=namespace)
# Out:
# {'kind': 'Status',
#  'apiVersion': 'v1',
#  'metadata': {},
#  'status': 'Success',
#  'details': {'name': 'mnist-service-577d',
#   'group': 'serving.kubeflow.org',
#   'kind': 'inferenceservices',
#   'uid': 'c86f603d-8df2-45cb-b41e-7fdfedeb20dd'}}

# %%
tfjob_client.delete(tfjob_name, namespace=my_namespace)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/kubeflow/tfjob/api/tf_job_client.py in delete(self, name, namespace)
#     190         name,
# --> 191         client.V1DeleteOptions())
#     192     except client.rest.ApiException as e:
#
# /usr/local/lib/python3.6/dist-packages/kubernetes/client/apis/custom_objects_api.py in delete_namespaced_custom_object(self, group, version, namespace, plural, name, body, **kwargs)
#     440         else:
# --> 441             (data) = self.delete_namespaced_custom_object_with_http_info(group, version, namespace, plural, name, body, **kwargs)
#     442             return data
#
# /usr/local/lib/python3.6/dist-packages/kubernetes/client/apis/custom_objects_api.py in delete_namespaced_custom_object_with_http_info(self, group, version, namespace, plural, name, body, **kwargs)
#     555                                         _request_timeout=params.get('_request_timeout'),
# --> 556                                         collection_formats=collection_formats)
#     557
#
# /usr/local/lib/python3.6/dist-packages/kubernetes/client/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     333                                    response_type, auth_settings,
# --> 334                                    _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     335         else:
#
# /usr/local/lib/python3.6/dist-packages/kubernetes/client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     167                                      _preload_content=_preload_content,
# --> 168                                      _request_timeout=_request_timeout)
#     169
#
# /usr/local/lib/python3.6/dist-packages/kubernetes/client/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     399                                            _request_timeout=_request_timeout,
# --> 400                                            body=body)
#     401         else:
#
# /usr/local/lib/python3.6/dist-packages/kubernetes/client/rest.py in DELETE(self, url, headers, query_params, body, _preload_content, _request_timeout)
#     255                             _request_timeout=_request_timeout,
# --> 256                             body=body)
#     257
#
# /usr/local/lib/python3.6/dist-packages/kubernetes/client/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     221         if not 200 <= r.status <= 299:
# --> 222             raise ApiException(http_resp=r)
#     223
#
# ApiException: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Cache-Control': 'no-cache, private', 'Content-Type': 'application/json', 'Date': 'Sat, 29 Aug 2020 08:51:16 GMT', 'Content-Length': '246'})
# HTTP response body: {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"tfjobs.kubeflow.org \"mnist-training-094d\" not found","reason":"NotFound","details":{"name":"mnist-training-094d","group":"kubeflow.org","kind":"tfjobs"},"code":404}
#
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-54-e484638696a0> in <module>
# ----> 1 tfjob_client.delete(tfjob_name, namespace=my_namespace)
#
# /usr/local/lib/python3.6/dist-packages/kubeflow/tfjob/api/tf_job_client.py in delete(self, name, namespace)
#     193       raise RuntimeError(
#     194         "Exception when calling CustomObjectsApi->delete_namespaced_custom_object:\
# --> 195          %s\n" % e)
#     196
#     197
#
# RuntimeError: Exception when calling CustomObjectsApi->delete_namespaced_custom_object:         (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Cache-Control': 'no-cache, private', 'Content-Type': 'application/json', 'Date': 'Sat, 29 Aug 2020 08:51:16 GMT', 'Content-Length': '246'})
# HTTP response body: {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"tfjobs.kubeflow.org \"mnist-training-094d\" not found","reason":"NotFound","details":{"name":"mnist-training-094d","group":"kubeflow.org","kind":"tfjobs"},"code":404}
